# %% [markdown]
# # Práctica 2
#
# Para esta práctica vamos a trabajar con una base de datos generada artificialmente. Esta se encuentra comprimida en el archivo **base.tar.gz**. Y esta organizada de la siguiente manera: un directorio llamado _BaseDatos_ con subdirectorios organizados por alcaldías y sectores. Dentro de cada sector se encuentran archivos cuyo nombre esta dado por una fecha y dentro de cada uno hay una lista con 40 nombres y telefonos (todos generados aleatoriamente). Para descomprimir la base de datos utiliza el comando:
#
# _**tar xzf base.tar.gz**_
#
# - ¿Qué tipo compresión es .tar.gz? ¿Cuál es la diferencia con la compresión .rar o .zip?
#
# Para esta práctica será de ayuda utilizar el comando **wc**(word counting)
#
# **wc -l** para contar líneas
#
# **wc -w** para contar palabras
#
# Si necesitas más información de este comando utiliza el manual
#
# #### Indicaciones
#
# - Sólo es válido usar comandos de Bash (no Python, ni algún otro lenguaje de programación)
# - Todos los comandos que uses (a menos que se indique lo contrario) deben de estar en el notebook.
# - Los archivos resultantes deben de colocarse en un directorio llamado __*resultado*__. Esta carpeta la deberás de comprimir y subirla al Classroom. El archivo que debes subir tiene que estar comprimido en un archivo .tar.gz para ello utilizarás el comando:
#
# _**tar czfv resultado.tar.gz resultado**_
#
# ## cat,  head, tail
#
# - Copia el archivo (utilizando comandos de bash) que se encuentra en _BaseDatos/TLALPAN/sectorH/names_2004-07-07.txt_ a la carpeta _**resultado**_.  Responde las siguientes preguntas
#
#     - Colócate en el directorio _**resultado**_ y ejecuta los siguientes comandos. ¿Cuál es el resultado de ejecutar el siguiente comando en la terminal? ¿Cuál es la diferencia entre estos dos? Explícalo con tus propias palabras.
#         - _cat < names_2004-07-07.txt > names_cat.txt_
#         -  _cat < names_2004-07-07.txt >> names_cat.txt_
#
#     - ¿Cuál es la diferencia entre estos comandos?
#         - _cat names.txt 2> err.dat_
#         - _cata names.txt 2> err.dat_
#
#     - Por último (lo debes ejecutar en una terminal) que sucede al hacer.
#         - cat > feliz + Ctrl+D
#
# - ¿Existe algúna forma con los comandos de bash de mostrar el archivo de forma inversa? En caso de existir, utilízalo para ver el archivo _BaseDatos/COYOACAN/sectorQ/names_2015-02-13.txt_ y guarda la salida en el archivo _catinverso.dat_
#
# - Crea un solo archivo con el nombre _todosarchivos.txt_ que tenga el contenido de todos los archivos del directorio _BaseDatos/CUAUHTEMOC/sectorF/_
#
# - Coloca en un archivo con el nombre _colacabeza_ las primeras 23 líneas numeradas y las últimas 32 líneas numeradas del archivo _todosarchivos.txt_
#
# <!-- Numera las linea.  Genera un archivo donde se indiquen con numeros las líneas de este archivo -->
#
# ## Permisos
#
# - Copia la carpeta CUAHTEMOC dentro de _**resultados**_ y cambia los permisos de todos los archivos de la siguiente manera sólo lectura y escritura para el dueño, sólo ejecución para el grupo y sólo lectura para los demás.
#
# ## find y grep
#
# - ¿Cuántos archivos tienen una extensión de .txt y cuántos tienen una extension .dat?
#
# - ¿Cuántos veces aparece tus nombres (sin apellido) en todos los archivos?
#
# - ¿En cuántos archivos __NO__ aparecen tus nombres?
#
# - ¿Cuántos veces coincide tus nombres con un archivo que tenga el año de tu nacimiento?
#
# - ¿De cuántos directorios y subdirectorios está compuesta la base de datos?
#
# - ¿Cuántos archivos tienen un tamaño menor a 1150 byte?
#
# - ¿Cuántos archivos coinciden con el año 2020 en su nombre y además pertencen al sectorS?
